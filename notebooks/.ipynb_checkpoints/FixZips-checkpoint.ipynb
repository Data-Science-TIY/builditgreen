# %%
import plotly.plotly as py
from plotly.graph_objs import *
import pandas as pd

# %%
# %matplotlib inline

# %%
latitude_df = pd.read_csv('zip_codes_states.csv')

# %%
latitude_df.head()
# Out:
#    zip_code   latitude  longitude        city state     county
# 0       501  40.922326 -72.637078  Holtsville    NY    Suffolk
# 1       544  40.922326 -72.637078  Holtsville    NY    Suffolk
# 2       601  18.165273 -66.722583    Adjuntas    PR   Adjuntas
# 3       602  18.393103 -67.180953      Aguada    PR     Aguada
# 4       603  18.455913 -67.145780   Aguadilla    PR  Aguadilla

# %%
city_state_lat = latitude_df.groupby(['city', 'state'], sort=True).first()

# %%
city_state_lat.head()
# Out:
#                   zip_code   latitude  longitude     county
# city       state
# APO        AP        96201        NaN        NaN        NaN
# Aaronsburg PA        16820  40.898690 -77.456184     Centre
# Abbeville  AL        36310  31.559402 -85.222965      Henry
#            GA        31001  31.977048 -83.372515     Wilcox
#            LA        70510  29.946603 -92.241595  Vermilion

# %%
leed_data = pd.read_csv('PublicLEEDProjectDirectory.csv', encoding="ISO-8859-1", header=3, low_memory=False)

# %%
leed_data.head()
# Out:
#          ID Isconfidential                              ProjectName  \
# 0  10000000             No                     PNC Firstside Center
# 1  10000001            Yes                             Confidential
# 2  10000002             No                 Bethel Commercial Center
# 3  10000003            Yes                             Confidential
# 4  10000004             No  The Chicago Center for Green Technology
#
#                        Street          City State       Zipcode Country  \
# 0  21 South Putt Corners Road    Pittsburgh    PA         15219      US
# 1                Confidential  Confidential    IN  Confidential      US
# 2               53 W. Jackson       Chicago    IL         60604      US
# 3                Confidential  Confidential    NY  Confidential      US
# 4    445 N. Sacramento Avenue       Chicago    IL         60612      US
#
#   LEEDSystemVersionDisplayName PointsAchieved CertLevel      CertDate  \
# ...

# %%
leed_data['City'] = leed_data['City'].map(lambda x: x.title())

# %%
projects_by_city = leed_data.groupby(['City', 'State']).size()

# %%
city_counts = projects_by_city.to_frame()

# %%
city_counts.columns = ['number of projects']

# %%
city_counts.head()
# Out:
#                   number of projects
# City       State
#                                  586
#            TX                      2
#  Beijing                           1
#  Calgary   AB                      1
#  Cleveland OH                      1

# %%
city_counts = city_counts.sort(['number of projects'], ascending=False)

# %%
city_counts = city_counts.reset_index()

# %%
city_state_lat.index.names = ['City', 'State']

# %%
city_state_lat = city_state_lat.reset_index()

# %%
df = city_state_lat.merge(city_counts, on=("City", "State"))

# %%
df.head()
# Out:
#                       City State  zip_code   latitude   longitude  \
# 0                 Aberdeen    MD     21001  39.499909  -76.231177
# 1                 Aberdeen    SD     57401  45.476172  -98.410405
# 2                 Aberdeen    WA     98520  47.002735 -123.671290
# 3  Aberdeen Proving Ground    MD     21005  39.477062  -76.120824
# 4                  Abilene    TX     79601  32.344457  -99.802130
#
#          county  number of projects
# 0       Harford                  25
# 1         Brown                   4
# 2  Grays Harbor                   3
# 3       Harford                   7
# 4        Taylor                   1

# %%
df = df.sort(['number of projects'], ascending=False)

# %%
df.head(20)
# Out:
#                City State  zip_code   latitude   longitude  \
# 4798     Washington    DC     20001  38.911936  -77.016719
# 1112         Dallas    TX     75201  32.781179  -96.790329
# 2141        Houston    TX     77001  29.813142  -95.309789
# 854         Chicago    IL     60601  41.811929  -87.687320
# 3221       New York    NY     10001  40.750422  -73.996328
# 2664    Los Angeles    CA     90001  33.973951 -118.248405
# 4076  San Francisco    CA     94101  37.784827 -122.727802
# 876      Cincinnati    OH     45201  39.166759  -84.538220
# 3741       Portland    OR     97201  45.498931 -122.693157
# 3609   Philadelphia    PA     19019  40.001811  -75.117870
# 4185        Seattle    WA     98101  47.432251 -121.803388
# 191         Atlanta    GA     30301  33.844371  -84.474050
# 3956      Rockville    MD     20847  39.143979  -77.207617
# 3205    New Orleans    LA     70112  29.958304  -90.077000
# 1183         Denver    CO     80201  39.726303 -104.856808
# ...

# %%
city_state_pop = pd.read_csv('city_state_pop.csv', encoding="ISO-8859-1")

# %%
city_state_pop.head()
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0          Alabama  Alabama       4779736            4780127          4785822
# 1   Abbeville city  Alabama          2688               2688             2681
# 2  Adamsville city  Alabama          4522               4522             4518
# 3     Addison town  Alabama           758                756              754
# 4       Akron town  Alabama           356                356              355
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014
# ...

# %%
city_state_pop_small = city_state_pop[['NAME', 'STNAME', 'POPESTIMATE2014']]

# %%
city_state_pop_small.head()
# Out:
#               NAME   STNAME  POPESTIMATE2014
# 0          Alabama  Alabama          4849377
# 1   Abbeville city  Alabama             2624
# 2  Adamsville city  Alabama             4435
# 3     Addison town  Alabama              749
# 4       Akron town  Alabama              338

# %%
city_state_pop_small.columns=['City', 'State', '2014 Population']

# %%
city_state_pop_small.head()
# Out:
#               City    State  2014 Population
# 0          Alabama  Alabama          4849377
# 1   Abbeville city  Alabama             2624
# 2  Adamsville city  Alabama             4435
# 3     Addison town  Alabama              749
# 4       Akron town  Alabama              338

# %%
city_state_pop_small.loc['city'] = city_state_pop_small['City'].map(lambda x: x.title())
# Out:
# /usr/local/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
city_state_pop_small.head()
# Out:
#               City    State  2014 Population
# 0          Alabama  Alabama          4849377
# 1   Abbeville city  Alabama             2624
# 2  Adamsville city  Alabama             4435
# 3     Addison town  Alabama              749
# 4       Akron town  Alabama              338

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    'District of Columbia': 'DC'
}

# %%
city_state_pop_small = city_state_pop_small.dropna()

# %%
city_state_pop_small['State'] = city_state_pop_small['State'].map(lambda x: us_state_abbrev[x])

# %%
city_state_pop_small.shape
# Out:
# (81611, 3)

# %%
df.head(100)
# Out:
#                City State  zip_code   latitude   longitude  \
# 4798     Washington    DC     20001  38.911936  -77.016719
# 1112         Dallas    TX     75201  32.781179  -96.790329
# 2141        Houston    TX     77001  29.813142  -95.309789
# 854         Chicago    IL     60601  41.811929  -87.687320
# 3221       New York    NY     10001  40.750422  -73.996328
# 2664    Los Angeles    CA     90001  33.973951 -118.248405
# 4076  San Francisco    CA     94101  37.784827 -122.727802
# 876      Cincinnati    OH     45201  39.166759  -84.538220
# 3741       Portland    OR     97201  45.498931 -122.693157
# 3609   Philadelphia    PA     19019  40.001811  -75.117870
# 4185        Seattle    WA     98101  47.432251 -121.803388
# 191         Atlanta    GA     30301  33.844371  -84.474050
# 3956      Rockville    MD     20847  39.143979  -77.207617
# 3205    New Orleans    LA     70112  29.958304  -90.077000
# 1183         Denver    CO     80201  39.726303 -104.856808
# ...

# %%
city_state_pop_small.head()
# Out:
#               City State  2014 Population
# 0          Alabama    AL          4849377
# 1   Abbeville city    AL             2624
# 2  Adamsville city    AL             4435
# 3     Addison town    AL              749
# 4       Akron town    AL              338

# %%
df[city_state_pop_small['City'] == "Nashville"]
# Out:
# /Users/joshuahiggins/tiyd/builditgreen/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/core/frame.py:1825: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# Empty DataFrame
# Columns: [City, State, zip_code, latitude, longitude, county, number of projects]
# Index: []

# %%
df.head()
# Out:
#             City State  zip_code   latitude  longitude                county  \
# 4798  Washington    DC     20001  38.911936 -77.016719  District Of Columbia
# 1112      Dallas    TX     75201  32.781179 -96.790329                Dallas
# 2141     Houston    TX     77001  29.813142 -95.309789                Harris
# 854      Chicago    IL     60601  41.811929 -87.687320                  Cook
# 3221    New York    NY     10001  40.750422 -73.996328              New York
#
#       number of projects
# 4798                1558
# 1112                 952
# 2141                 933
# 854                  900
# 3221                 836

# %%
df[df['State']=='TN']
# Out:
#                      City State  zip_code   latitude  longitude      county  \
# 3149            Nashville    TN     37201  36.165688 -86.778098    Davidson
# 2404            Knoxville    TN     37901  36.032334 -83.884804        Knox
# 821           Chattanooga    TN     37401  35.017818 -85.206426    Hamilton
# 2885              Memphis    TN     37501  35.169255 -89.990415      Shelby
# 127               Antioch    TN     37011  36.170556 -86.882500    Davidson
# 1652             Franklin    TN     37064  35.890746 -86.965691  Williamson
# 3353            Oak Ridge    TN     37830  36.019381 -84.243175    Anderson
# 3123         Murfreesboro    TN     37127  35.762951 -86.372158  Rutherford
# 47                  Alcoa    TN     37701  35.815758 -83.987698      Blount
# 914             Cleveland    TN     37311  35.149223 -84.874031     Bradley
# 2723              Madison    TN     37115  36.259503 -86.706296    Davidson
# ...

# %%
population_df = pd.read_csv('population.csv', header=1)

# %%
population_df.head()
# Out:
#    Unnamed: 0         Place         State     Census Estimates Base  \
# 0           1      New York      New York  8,175,133      8,175,133
# 1           2   Los Angeles    California  3,792,621      3,792,625
# 2           3       Chicago      Illinois  2,695,598      2,695,598
# 3           4       Houston         Texas  2,099,451      2,099,430
# 4           5  Philadelphia  Pennsylvania  1,526,006      1,526,006
#
#         2010       2011  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0  8,186,443  8,244,910         NaN         NaN         NaN          NaN
# 1  3,795,761  3,819,702         NaN         NaN         NaN          NaN
# 2  2,698,283  2,707,120         NaN         NaN         NaN          NaN
# 3  2,108,278  2,145,146         NaN         NaN         NaN          NaN
# 4  1,528,074  1,536,471         NaN         NaN         NaN          NaN

# %%
population_df['State'] = population_df['State'].map(lambda x: us_state_abbrev[x])

# %%
population_df.head()
# Out:
#    Unnamed: 0         Place State     Census Estimates Base       2010  \
# 0           1      New York    NY  8,175,133      8,175,133  8,186,443
# 1           2   Los Angeles    CA  3,792,621      3,792,625  3,795,761
# 2           3       Chicago    IL  2,695,598      2,695,598  2,698,283
# 3           4       Houston    TX  2,099,451      2,099,430  2,108,278
# 4           5  Philadelphia    PA  1,526,006      1,526,006  1,528,074
#
#         2011  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0  8,244,910         NaN         NaN         NaN          NaN
# 1  3,819,702         NaN         NaN         NaN          NaN
# 2  2,707,120         NaN         NaN         NaN          NaN
# 3  2,145,146         NaN         NaN         NaN          NaN
# 4  1,536,471         NaN         NaN         NaN          NaN

# %%
population_df = population_df[['Place', 'State', 'Census']]

# %%
population_df.head()
# Out:
#           Place State     Census
# 0      New York    NY  8,175,133
# 1   Los Angeles    CA  3,792,621
# 2       Chicago    IL  2,695,598
# 3       Houston    TX  2,099,451
# 4  Philadelphia    PA  1,526,006

# %%
population_df['Census'] = population_df['Census'].map(lambda x: x.replace(",", ""))

# %%
population_df.head()
# Out:
#           Place State   Census
# 0      New York    NY  8175133
# 1   Los Angeles    CA  3792621
# 2       Chicago    IL  2695598
# 3       Houston    TX  2099451
# 4  Philadelphia    PA  1526006

# %%
population_df['Census'] = population_df['Census'].map(lambda x: x.replace("(X)", "0"))

# %%
population_df['Census'] = population_df['Census'].map(lambda x: int(x))

# %%
population_df.columns = ['City', 'State', 'Population']

# %%
population_df.head()
# Out:
#            City State  Population
# 0      New York    NY     8175133
# 1   Los Angeles    CA     3792621
# 2       Chicago    IL     2695598
# 3       Houston    TX     2099451
# 4  Philadelphia    PA     1526006

# %%
population_df[population_df['State'] == "AK"]
# Out:
#          City State  Population
# 64  Anchorage    AK      291826

# %%
population_df[population_df['State'] == "HI"]
# Out:
#         City State  Population
# 54  Honolulu    HI      337256

# %%
population_df[population_df['State'] == "CA"]
# Out:
#                  City State  Population
# 1         Los Angeles    CA     3792621
# 7           San Diego    CA     1307402
# 9            San Jose    CA      945942
# 13      San Francisco    CA      805235
# 33             Fresno    CA      494665
# 34         Sacramento    CA      466488
# 35         Long Beach    CA      462257
# 45            Oakland    CA      390724
# 51        Bakersfield    CA      347483
# 53            Anaheim    CA      336265
# 56          Santa Ana    CA      324528
# 58          Riverside    CA      303871
# 62           Stockton    CA      291707
# 75        Chula Vista    CA      243916
# 94            Fremont    CA      214089
# 95             Irvine    CA      212375
# 96     San Bernardino    CA      209924
# 106           Modesto    CA      201165
# 109            Oxnard    CA      197899
# 111           Fontana    CA      196069
# 113     Moreno Valley    CA      193365
# 120          Glendale    CA      191719
# ...

# %%
df_all = population_df.merge(df, on=('City', 'State'))

# %%
df_all.shape
# Out:
# (592, 8)

# %%
df_num_projects_sorted = df_all.sort(['number of projects'], ascending=False)

# %%
df_num_projects_sorted.shape
# Out:
# (592, 8)

# %%
df_num_projects_sorted[df_num_projects_sorted['City'] == "Honolulu"]
# Out:
#         City State  Population  zip_code   latitude   longitude    county  \
# 51  Honolulu    HI      337256     96801  24.859832 -168.021815  Honolulu
#
#     number of projects                                text
# 51                 480  Honolulu<br>Number of Projects 480

# %%
df_num_projects_sorted.head(10)
# Out:
#              City State  Population  zip_code   latitude   longitude  \
# 23     Washington    DC      601723     20001  38.911936  -77.016719
# 8          Dallas    TX     1197816     75201  32.781179  -96.790329
# 3         Houston    TX     2099451     77001  29.813142  -95.309789
# 2         Chicago    IL     2695598     60601  41.811929  -87.687320
# 0        New York    NY     8175133     10001  40.750422  -73.996328
# 1     Los Angeles    CA     3792621     90001  33.973951 -118.248405
# 12  San Francisco    CA      805235     94101  37.784827 -122.727802
# 58     Cincinnati    OH      296943     45201  39.166759  -84.538220
# 27       Portland    OR      583776     97201  45.498931 -122.693157
# 4    Philadelphia    PA     1526006     19019  40.001811  -75.117870
#
#                   county  number of projects  \
# 23  District Of Columbia                1558
# 8                 Dallas                 952
# 3                 Harris                 933
# ...

# %%
df_num_projects_sorted = df_num_projects_sorted[df_num_projects_sorted['City'] != "Honolulu"]

# %%
df_num_projects_sorted[df_num_projects_sorted['City'] == "Honolulu"]
# Out:
# Empty DataFrame
# Columns: [City, State, Population, zip_code, latitude, longitude, county, number of projects, text]
# Index: []

# %%
df_num_projects_sorted['text'] = df_num_projects_sorted['City'] + '<br>Number of Projects ' + (df_num_projects_sorted['number of projects']).astype(str)
limits = [(0,6),(6,16),(15,31),(31,51),(51,500)]
colors = ["rgb(0, 255, 181)","rgb(255, 224, 0)","rgb(30, 111, 255)","rgb(235, 108, 72)","rgb(93, 0, 169)"]

cities = []
scale = 15

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df_num_projects_sorted[lim[0]:lim[1]]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_sub['longitude'],
        lat = df_sub['latitude'],
        text = df_sub['text'],
        sizemode = 'diameter',
        marker = dict( 
            size = df_sub['number of projects']/scale, 
            color = colors[i],
            line = dict(width = 2,color = 'black')
        ),
        name = 'LEED Projects: {0} - {1}'.format(df_num_projects_sorted.iloc[lim[0],7],
                                            df_num_projects_sorted.iloc[lim[1],7]))
    cities.append(city)

layout = dict(
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',       
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"           
        ),  
    )
    
fig = dict( data=cities, layout=layout )
fig['layout'].update(
    autosize=False,  # allow custom size (set already, only for completeness here)
    width=960,    # link new width value
    height=453,  # link new height value
#     font=Font(size=7),       # update global font size
#     titlefont=Font(size=12)  #  as well as the title font size 
)
layout.update(margin=Margin(l=0,r=0,b=0,t=0,pad=0,autoexpand=True))
py.iplot( fig, validate=False, filename='d3-bubble-map-leed-500' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~jdhiggins/41.embed" height="525" width="100%"></iframe>

# %% [markdown]
# Which cities have the largest number of LEED projects?  Washington, DC, with its strong federal government influence, has the largest number of projects by far.  Charlotte leeds the way in North Carolina with 333 projects.  Explore how your city is doing in this interactive map.

# %%
df_all['population_adjusted'] = df_all['number of projects']/df_all['Population']*10000

# %%
df_all.head()
# Out:
#            City State  Population  zip_code   latitude   longitude  \
# 0      New York    NY     8175133     10001  40.750422  -73.996328
# 1   Los Angeles    CA     3792621     90001  33.973951 -118.248405
# 2       Chicago    IL     2695598     60601  41.811929  -87.687320
# 3       Houston    TX     2099451     77001  29.813142  -95.309789
# 4  Philadelphia    PA     1526006     19019  40.001811  -75.117870
#
#          county  number of projects  population_adjusted
# 0      New York                 836             1.022613
# 1   Los Angeles                 780             2.056625
# 2          Cook                 900             3.338777
# 3        Harris                 933             4.444019
# 4  Philadelphia                 599             3.925279

# %%
df_pop_adj_sort = df_all.sort(['population_adjusted'], ascending=False)

# %%
df_pop_adj_sort
# Out:
#                 City State  Population  zip_code   latitude   longitude  \
# 465        Rockville    MD       61209     20847  39.143979  -77.207617
# 415         Santa Fe    NM       67947     87500  35.697473 -105.982146
# 155       Alexandria    VA      139966     22301  38.823062  -77.079622
# 111     Grand Rapids    MI      188040     49501  42.984226  -85.629101
# 23        Washington    DC      601723     20001  38.911936  -77.016719
# 238       Round Rock    TX       99887     78664  30.530497  -97.635103
# 589        Bradenton    FL       49546     34201  27.404731  -82.470456
# 405     Jacksonville    NC       70145     28540  34.726587  -77.414673
# 564         Sarasota    FL       51917     34230  27.335023  -82.537169
# 58        Cincinnati    OH      296943     45201  39.166759  -84.538220
# 480          Meriden    CT       60868      6450  41.536498  -72.801901
# 231        Cambridge    MA      105162      2138  42.380442  -71.132947
# ...

# %%
df_pop_adj_sort[df_pop_adj_sort['State'] == "AK"]
# Out:
#          City State  Population  zip_code   latitude   longitude     county  \
# 59  Anchorage    AK      291826     99501  61.287624 -149.486981  Anchorage
#
#     number of projects  population_adjusted
# 59                  22             0.753874

# %%
df_pop_adj_sort.head()
# Out:
#              City State  Population  zip_code   latitude   longitude  \
# 465     Rockville    MD       61209     20847  39.143979  -77.207617
# 415      Santa Fe    NM       67947     87500  35.697473 -105.982146
# 155    Alexandria    VA      139966     22301  38.823062  -77.079622
# 111  Grand Rapids    MI      188040     49501  42.984226  -85.629101
# 23     Washington    DC      601723     20001  38.911936  -77.016719
#
#                    county  number of projects  population_adjusted
# 465            Montgomery                 544            88.875819
# 415              Santa Fe                 285            41.944457
# 155       Alexandria City                 421            30.078733
# 111                  Kent                 505            26.855988
# 23   District Of Columbia                1558            25.892313

# %%
df_pop_adj_sort[df_pop_adj_sort['City'] == "Honolulu"]
# Out:
#         City State  Population  zip_code   latitude   longitude    county  \
# 51  Honolulu    HI      337256     96801  24.859832 -168.021815  Honolulu
#
#     number of projects  population_adjusted  \
# 51                 480            14.232512
#
#                                                  text
# 51  Honolulu<br>Number of Projects per 10000 14.23...

# %%
df_pop_adj_sort_1 = df_pop_adj_sort[df_pop_adj_sort['City'] != "Honolulu"]

# %%
df_pop_adj_sort_1[df_pop_adj_sort_1['City'] == "Honolulu"]
# Out:
# Empty DataFrame
# Columns: [City, State, Population, zip_code, latitude, longitude, county, number of projects, population_adjusted, text]
# Index: []

# %%
df_pop_adj_sort = df_pop_adj_sort_1

# %%
df_pop_adj_sort['text'] = df_pop_adj_sort['City'] + '<br>Number of Projects per 10000 ' + (df_pop_adj_sort['population_adjusted']).astype(str)
limits = [(0,6),(6,16),(16,31),(31,51),(51,500)]
colors = ["rgb(30, 111, 255)","rgb(255, 224, 0)","rgb(0, 255, 181)","rgb(235, 108, 72)","rgb(93, 0, 169)"]

cities = []
scale = 1

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df_pop_adj_sort[lim[0]:lim[1]]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_sub['longitude'],
        lat = df_sub['latitude'],
        text = df_sub['text'],
        sizemode = 'diameter',
        marker = dict( 
            size = df_sub['population_adjusted']/scale, 
            color = colors[i],
            line = dict(width = 2,color = 'black')
        ),
        name = 'Projects/10,000 Residents: {0} - {1}'.format(int(df_pop_adj_sort.iloc[lim[0],8]),
                                            int(df_pop_adj_sort.iloc[lim[1],8])))
    cities.append(city)

layout = dict(
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',       
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"           
        ),  
    )
    
fig = dict( data=cities, layout=layout )
fig['layout'].update(
    autosize=False,  # allow custom size (set already, only for completeness here)
    width=960,    # link new width value
    height=453,  # link new height value
#     font=Font(size=7),       # update global font size
#     titlefont=Font(size=12)  #  as well as the title font size 
)
layout.update(margin=Margin(l=0,r=0,b=0,t=0,pad=0,autoexpand=True))
py.iplot( fig, validate=False, filename='d3-bubble-map-leed_adjusted_500' )
# Out:
# /usr/local/lib/python3.4/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~jdhiggins/43.embed" height="525" width="100%"></iframe>

# %% [markdown]
# After adjusting for population, how do cities perform?  Smaller cities shine here, with many DC suburbs outperforming -- no doubt with many federal projects increasing their totals. In North Carolina, Jacksonville and Wilmington peform well on this adjusted scale. Explore how your city is doing in this interactive map.

# %%
df_pop_adj_sort.to_pickle("project_by_adj_population.pkl")

# %%
df_num_projects_sorted.to_pickle("project_by_num_projects.pkl")

# %%
df_pop_adj_sort[df_pop_adj_sort['City'] == "Durham"]
# Out:
#       City State  Population  zip_code   latitude  longitude  county  \
# 75  Durham    NC      228330     27701  36.004307 -78.875467  Durham
#
#     number of projects  population_adjusted  \
# 75                 105             4.598607
#
#                                                  text
# 75  Durham<br>Number of Projects per 10000 4.59860...

# %% [markdown]
# alaska, hawaii, add above 50k to legend

# %%
df_pop_adj_sort_1['text'] = df_pop_adj_sort_1['City'] + '<br>Number of Projects per 10000 ' + (df_pop_adj_sort_1['population_adjusted']).astype(str)
limits = [(0,6),(6,16),(16,31),(31,51),(51,500)]
colors = ["rgb(30, 111, 255)","rgb(255, 224, 0)","rgb(0, 255, 181)","rgb(235, 108, 72)","rgb(93, 0, 169)"]

cities = []
scale = 1

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df_pop_adj_sort_1[lim[0]:lim[1]]
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_sub['longitude'],
        lat = df_sub['latitude'],
        text = df_sub['text'],
        sizemode = 'diameter',
        marker = dict( 
            size = df_sub['population_adjusted']/scale, 
            color = colors[i],
            line = dict(width = 2,color = 'black')
        ),
        name = 'Projects/10,000 Residents: {0} - {1}'.format(int(df_pop_adj_sort_1.iloc[lim[0],8]),
                                            int(df_pop_adj_sort_1.iloc[lim[1],8])))
    cities.append(city)

layout = dict(
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',       
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"           
        ),  
    )
    
fig = dict( data=cities, layout=layout )
fig['layout'].update(
    autosize=False,  # allow custom size (set already, only for completeness here)
    width=960,    # link new width value
    height=453,  # link new height value
#     font=Font(size=7),       # update global font size
#     titlefont=Font(size=12)  #  as well as the title font size 
)
layout.update(margin=Margin(l=0,r=0,b=0,t=0,pad=0,autoexpand=True))
py.iplot( fig, validate=False, filename='d3-bubble-map-leed_adjusted_500_no_honolulu' )
# Out:
# /usr/local/lib/python3.4/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~jdhiggins/118.embed" height="525" width="100%"></iframe>
